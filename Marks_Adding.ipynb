# %% [markdown]
# <a href="https://colab.research.google.com/github/aanasingla/aana-the-techie/blob/main/Marks_Adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create the input.csv file with the provided data
data = """Roll Num,Marks
102003542,1
102003640,3
102003725,1
102003307,1
102003643,1
102017134,1
"""

with open("input.csv", "w") as f:
    f.write(data)

print("input.csv created succesfully.")
# Out:
# input.csv created succesfully.

# %%
import csv
from collections import defaultdict

# Step 1: Read input from a file (input.csv)
marks_dict = defaultdict(int)

with open("input.csv", mode="r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    for row in reader:
        roll_num = row[0]
        marks = int(row[1])
        marks_dict[roll_num] += marks

# Step 2: Write to output file (output.csv)
with open("output.csv", mode="w", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Roll Num", "Marks"])
    for roll_num, total_marks in marks_dict.items():
        writer.writerow([roll_num, total_marks])

print("✅ Marks have been summed and written to output.csv")
# Out:
# ✅ Marks have been summed and written to output.csv

# %%
import pandas as pd

# Load the output CSV file
output_df = pd.read_csv("output.csv")

# Display the content
print("📄 Output CSV Content:")
print(output_df)

# Optional: display as a table
output_df.head()
# Out:
# 📄 Output CSV Content:
#     Roll Num  Marks
# 0  102003542      1
# 1  102003640      3
# 2  102003725      1
# 3  102003307      1
# 4  102003643      1
# 5  102017134      1
#     Roll Num  Marks
# 0  102003542      1
# 1  102003640      3
# 2  102003725      1
# 3  102003307      1
# 4  102003643      1
